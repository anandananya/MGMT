# %%
import pydicom as dicom
import numpy as np
import matplotlib.pylab as plt
import scipy

import time
import os
import csv

from skimage.transform import resize
from ipywidgets import interact, interactive, IntSlider, ToggleButtons

import cv2
import numpy as np

# Import Densenet from Keras
from keras.applications.densenet import DenseNet121
from keras.layers import Input, merge, ZeroPadding2D
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.convolutional import Convolution2D
from keras.layers.pooling import AveragePooling2D, GlobalAveragePooling2D, MaxPooling2D
from keras.models import Model
from keras import backend as K

from scipy.ndimage import zoom
from numpy import save, load

mgmt_dictionary = {}
with open('/Users/user/Desktop/rsna-miccai-brain-tumor-radiogenomic-classification/train_labels.csv', 'r') as csvfile:
    csvreader = csv.reader(csvfile)
    fields = next(csvreader)
    for row in csvreader:        
        mgmt_dictionary[row[0]] = int(row[1])
print(mgmt_dictionary)

def affine_tranformation(patient_id, numSlices):
    image_path = '/Users/user/Desktop/rsna-miccai-brain-tumor-radiogenomic-classification/train/'+patient_id+'/T1wCE/'
    last_image_path = image_path + 'Image-' + str(numSlices) + '.dcm'
    # print("image path %s" % last_image_path)
    ds = dicom.dcmread(last_image_path)
    # print("Patient ID: %s" % patient_id)
    rows=0
    columns=0
    for value in ds:
        str_value = str(value).rstrip('\n')
        if 'Rows' in str_value:
            rows = int(str_value.split(':')[1])
        if 'Columns' in str_value:
            columns = int(str_value.split(':')[1])
        if 'Image Position (Patient)' in str_value:
            image_position_str = str_value.split(':')[1]
            # print(image_position_str)
            image_position_str = image_position_str.rstrip(']')
            image_position_str = image_position_str.lstrip()
            image_position_str = image_position_str.lstrip('[')
            TNx = float(image_position_str.split(',')[0])
            TNy = float(image_position_str.split(',')[1])
            TNz = float(image_position_str.split(',')[2])
            # print("TNx, TNy, TNz: (%f,%f,%f)" % (TNx, TNy, TNz))
    first_image_path = image_path + 'Image-1.dcm'
    # print("image path %s" % first_image_path)
    ds = dicom.dcmread(first_image_path)
    for value in ds:
        str_value = str(value).rstrip('\n')
        if 'Rows' in str_value:
            rows = int(str_value.split(':')[1])
        if 'Columns' in str_value:
            columns = int(str_value.split(':')[1])
        if 'Image Position (Patient)' in str_value:
            image_position_str = str_value.split(':')[1]
            # print(image_position_str)
            image_position_str = image_position_str.rstrip('\]')
            image_position_str = image_position_str.lstrip()
            image_position_str = image_position_str.lstrip('\[')
            T1x = float(image_position_str.split(',')[0])
            T1y = float(image_position_str.split(',')[1])
            T1z = float(image_position_str.split(',')[2])
            # print("T1x, T1y, T1z: (%f,%f,%f)" % (T1x, T1y, T1z))
    k1 = (TNx - T1x)/(numSlices-1)
    k2 = (TNy - T1y)/(numSlices-1)
    k3 = (TNz - T1z)/(numSlices-1)
    Px = []
    Py = []
    Pz = []
    # print("Rows: %d, Columns: %d, numSlices: %d" % (rows, columns, numSlices))
    values=np.empty((rows,columns,numSlices))
    for z in range(0, numSlices):
        #if z % 30 == 0:
        print('Affine tranformation - slice %d' % z)
        image_path = '/Users/user/Desktop/rsna-miccai-brain-tumor-radiogenomic-classification/train/'+patient_id+'/T1wCE/Image-'+str(z+1)+'.dcm'
        if os.path.exists(image_path):
            # print("Image path: %s" % image_path)
            ds = dicom.dcmread(image_path)
            slice_spacing = 0
            slice_thickness = 0
            for value in ds:
                str_value = str(value).rstrip('\n')
                if 'Rows' in str_value:
                    rows = int(str_value.split(':')[1])
                    # print("Num Rows: %d" % rows)
                if 'Columns' in str_value:
                    columns = int(str_value.split(':')[1])
                    # print("Num Columns: %d" % columns)
                if 'Slice Thickness' in str_value:
                    slice_thickness = float(str_value.split('\'')[1])
                if 'Spacing Between Slices' in str_value:
                    slice_spacing = float(str_value.split('\'')[1])
                if 'Image Position (Patient)' in str_value:
                    image_position_str = str_value.split(':')[1]
                    image_position_str = image_position_str.rstrip(']')
                    image_position_str = image_position_str.lstrip()
                    image_position_str = image_position_str.lstrip('[')
                    sx = float(image_position_str.split(',')[0])
                    sy = float(image_position_str.split(',')[1])
                    sz = float(image_position_str.split(',')[2])
                if 'Image Orientation (Patient)' in str_value:
                    image_orientation_str = str_value.split(':')[1]
                    image_orientation_str = image_orientation_str.rstrip(']')
                    image_orientation_str = image_orientation_str.lstrip()
                    image_orientation_str = image_orientation_str.lstrip('[')
                    Xx = float(image_orientation_str.split(',')[0])
                    Xy = float(image_orientation_str.split(',')[1])
                    Xz = float(image_orientation_str.split(',')[2])
                    Yx = float(image_orientation_str.split(',')[3])
                    Yy = float(image_orientation_str.split(',')[4])
                    Yz = float(image_orientation_str.split(',')[5])
                    X = [Xx, Xy, Xz]
                    Y = [Yx, Yy, Yz]
                if 'Pixel Spacing' in str_value:
                    pixel_spacing_str = str_value.split(':')[1]
                    pixel_spacing_str = pixel_spacing_str.rstrip(']')
                    pixel_spacing_str = pixel_spacing_str.lstrip()
                    pixel_spacing_str = pixel_spacing_str.lstrip('[')
                    dx = float(pixel_spacing_str.split(',')[0])
                    dy = float(pixel_spacing_str.split(',')[1])
            dz = slice_spacing + slice_thickness
            A = np.empty((4,4))
            A[0][0] = Xx * dx
            A[1][0] = Xy * dx
            A[2][0] = Xz * dx
            A[3][0] = 0
            A[0][1] = Yx * dy
            A[1][1] = Yy * dy
            A[2][1] = Yz * dy
            A[3][1] = 0
            A[0][2] = k1
            A[1][2] = k2
            A[2][2] = k3
            A[3][2] = 0
            A[0][3] = sx
            A[1][3] = sy
            A[2][3] = sz
            A[3][3] = float(1.0)
            V = np.empty((4,1))
            # print("sz: %f" % sz)
            # print("k3: %f" % k3)
            for r in range(0, rows):
                for c in range(0, columns):
                    V[0] = r
                    V[1] = c
                    V[2] = z
                    V[3] = 1
                    P = np.matmul(A, V)
                    Px.extend(P[0])
                    Py.extend(P[1])
                    Pz.extend(P[2])
            # print("Px len: %d" % len(Px))
            img2=np.uint8(cv2.normalize(ds.pixel_array, None, 0, 255, cv2.NORM_MINMAX))
            equalizedImage = cv2.equalizeHist(img2)
            plt.imshow(equalizedImage, cmap=plt.cm.gray)
            for x in range(0,rows):
                for y in range(0,columns):
                    values[x][y][z] = equalizedImage[x][y]

    # print("Values array size: %d" % (rows*columns*numSlices))
    return Px,Py,Pz,values

COMPRESSION_RATIO=.125

DICOM_UNIFORM_ROWS=64
DICOM_UNIFORM_COLUMNS=64
DICOM_UNIFORM_SLICES=32

PATCH_SIZE_X=64
PATCH_SIZE_Y=64
PATCH_SIZE_Z=32

# DICOM_UNIFORM_ROWS=128
# DICOM_UNIFORM_COLUMNS=128
# DICOM_UNIFORM_SLICES=96
# PATCH_SIZE_X=120
# PATCH_SIZE_Y=120
# PATCH_SIZE_Z=30

def nearest_neighbor_interpolation(Px, Py, Pz, values):
    px = np.array(Px)
    py = np.array(Py)
    pz = np.array(Pz)
    points = np.array((Px, Py, Pz)).T
    
    # Assuming you want 512x512x256 datapoints from all patient scans
    delta_x = px[len(px)-1]-px[0]/DICOM_UNIFORM_ROWS
    delta_y = py[len(py)-1]-py[0]/DICOM_UNIFORM_COLUMNS
    delta_z = pz[len(pz)-1]-pz[0]/DICOM_UNIFORM_SLICES

    print("Nearest Neighbor interpolation started")
    nearest_interp = scipy.interpolate.NearestNDInterpolator(points, values) 
    for x in range(0,DICOM_UNIFORM_ROWS):
        for y in range(0,DICOM_UNIFORM_COLUMNS):
            for z in range(0,DICOM_UNIFORM_SLICES):
                point_x = x * delta_x
                point_y = y * delta_y
                point_z = z * delta_z
                point = np.array([point_x,point_y,point_z])
                interpolated_image[x][y][z] = nearest_interp(point)
    
    print("Uniform interpolation done")    
    return interpolated_image

def create_patches(image_data):
    print("Creating patches")
    patches = []
    patch = np.empty((PATCH_SIZE_X,PATCH_SIZE_Y,PATCH_SIZE_Z))
    width, height, depth = image_data.shape
    nx_patches = width/PATCH_SIZE_X
    ny_patches = height/PATCH_SIZE_Y
    nz_patches = depth/PATCH_SIZE_Z
    for x in range(0,width,PATCH_SIZE_X):
        for y in range(0,height,PATCH_SIZE_Y):
            for z in range(0,depth,PATCH_SIZE_Z):
                if z+PATCH_SIZE_Z > depth:
                    break
                for px in range(0,PATCH_SIZE_X):
                    for py in range(0,PATCH_SIZE_Y):
                        for pz in range(0,PATCH_SIZE_Z):
                            patch[px][py][pz] = image_data[x+px][y+py][z+pz]
                patches.append(patch)
                # print("patch count: %d" % len(patches))
            if y+PATCH_SIZE_Y > height:
                break
        if x+PATCH_SIZE_X > width:
            break
    print("Final patch count: %d" % len(patches))
    return patches

def save_patches(patient_id, patches):
    print("Saving patches for patient %s", patient_id)
    for patch_num, patch in enumerate(patches):
        patch_array = np.array(patch)
        output_file = 'Dicom/dicom_' + patient_id + '_' + str(patch_num) + '.npy'
        save(output_file, patch_array)
    return patches

def compress_image(Px, Py, Pz, values, x_scale, y_scale, z_scale):
    print("Compression started, scale: (%f,%f,%f)" % (x_scale, y_scale, z_scale))
    compressed_values = zoom(values, (x_scale, y_scale, z_scale))
    count = 0
    zoom_x = []
    zoom_y = []
    zoom_z = []
    width, height, depth = values.shape
    zoom_values = np.empty((int(width*height*depth*x_scale*y_scale*z_scale)))
    for x in range(0,int(width*x_scale)):
        for y in range(0,int(height*y_scale)):
            for z in range(0,int(depth*z_scale)):
                zoom_values[count] = compressed_values[x][y][z]
                zoom_x.append(int(Px[int(x/x_scale)]*x_scale));
                zoom_y.append(int(Py[int(y/y_scale)]*y_scale));
                zoom_z.append(int(Pz[int(z/z_scale)]*z_scale));    
                count = count + 1
                   
    return zoom_x, zoom_y, zoom_z, zoom_values

def load_patch(patient_id, patch_num):
    print("Loading patch, Patient id: %s, Patch num: %d" % (patient_id, patch_num))
    patch_file = 'Dicom/dicom_' + patient_id + '_' + str(patch_num) + '.npy'
    patch_array = np.load(patch_file)
    print(patch_array)
 
interpolated_image = np.empty((DICOM_UNIFORM_ROWS,DICOM_UNIFORM_COLUMNS,DICOM_UNIFORM_SLICES))        
for patient_folder in os.listdir('/Users/user/Desktop/rsna-miccai-brain-tumor-radiogenomic-classification/train/'):
    # if patient_folder != '.DS_Store':
    image_path = '/Users/user/Desktop/rsna-miccai-brain-tumor-radiogenomic-classification/train/'+patient_folder+'/T1wCE/'
    numSlices = len([name for name in os.listdir(image_path)])
    # numSlices = 8
    print('Patient %d Num Slices %d' % (int(patient_folder), numSlices))
    Px,Py,Pz,values = affine_tranformation(patient_folder, numSlices)
    print("Affine transformation completed")
    Px,Py,Pz,compressed_values = compress_image(Px,Py,Pz,values,COMPRESSION_RATIO,COMPRESSION_RATIO,COMPRESSION_RATIO)
    print("Compression completed")
    interpolated_image = nearest_neighbor_interpolation(Px,Py,Pz,compressed_values)
    print("Nearest Neighbor interpolation completed")
    patches = create_patches(interpolated_image)
    print("Creating Patches completed")
    save_patches(patient_folder,patches)
    print("Save Patches completed")
    break
    
def explore_3dimage(layer):
    plt.figure(figsize=(10, 5))
    plt.imshow(interpolated_image[:, :, layer], cmap='gray')
    plt.title('Explore Layers of Brain MRI', fontsize=20)
    plt.axis('off')
    return layer

interact(explore_3dimage, layer=(0, interpolated_image.shape[2]-1))
# Out:
# {'00000': 1, '00002': 1, '00003': 0, '00005': 1, '00006': 1, '00008': 1, '00009': 0, '00011': 1, '00012': 1, '00014': 1, '00017': 0, '00018': 0, '00019': 0, '00020': 1, '00021': 0, '00022': 0, '00024': 0, '00025': 1, '00026': 1, '00028': 1, '00030': 0, '00031': 1, '00032': 0, '00033': 1, '00035': 1, '00036': 0, '00043': 1, '00044': 0, '00045': 0, '00046': 1, '00048': 1, '00049': 0, '00052': 1, '00053': 0, '00054': 1, '00056': 1, '00058': 1, '00059': 1, '00060': 1, '00061': 0, '00062': 1, '00063': 1, '00064': 0, '00066': 1, '00068': 1, '00070': 1, '00071': 1, '00072': 0, '00074': 1, '00077': 1, '00078': 1, '00081': 0, '00084': 0, '00085': 1, '00087': 1, '00088': 0, '00089': 1, '00090': 0, '00094': 1, '00095': 0, '00096': 1, '00097': 0, '00098': 1, '00099': 0, '00100': 1, '00102': 0, '00104': 0, '00105': 1, '00106': 1, '00107': 1, '00108': 0, '00109': 1, '00110': 0, '00111': 0, '00112': 0, '00113': 0, '00116': 0, '00117': 1, '00120': 1, '00121': 0, '00122': 0, '00123': 0, '00124': 0, '00128': 1, '00130': 0, '00132': 0, '00133': 0, '00134': 1, '00136': 1, '00137': 0, '00138': 1, '00139': 1, '00140': 1, '00142': 0, '00143': 1, '00144': 1, '00146': 1, '00147': 0, '00148': 0, '00149': 0, '00150': 0, '00151': 0, '00154': 0, '00155': 1, '00156': 1, '00157': 0, '00158': 0, '00159': 1, '00160': 1, '00162': 0, '00165': 0, '00166': 1, '00167': 0, '00169': 0, '00170': 0, '00171': 1, '00172': 0, '00176': 0, '00177': 1, '00178': 1, '00183': 0, '00184': 0, '00185': 1, '00186': 1, '00187': 1, '00188': 1, '00191': 0, '00192': 0, '00193': 0, '00194': 0, '00195': 0, '00196': 1, '00197': 1, '00199': 1, '00201': 0, '00203': 1, '00204': 1, '00206': 0, '00209': 0, '00210': 1, '00211': 0, '00212': 1, '00214': 0, '00216': 0, '00217': 0, '00218': 0, '00219': 0, '00220': 1, '00221': 0, '00222': 1, '00227': 0, '00228': 0, '00230': 1, '00231': 0, '00233': 1, '00234': 1, '00235': 1, '00236': 0, '00237': 0, '00238': 0, '00239': 0, '00240': 1, '00241': 0, '00242': 0, '00243': 0, '00245': 1, '00246': 1, '00247': 0, '00249': 0, '00250': 1, '00251': 0, '00253': 1, '00254': 1, '00258': 0, '00259': 0, '00260': 1, '00261': 0, '00262': 0, '00263': 1, '00266': 0, '00267': 0, '00269': 0, '00270': 1, '00271': 1, '00273': 1, '00274': 0, '00275': 0, '00280': 0, '00281': 1, '00282': 1, '00283': 0, '00284': 1, '00285': 1, '00286': 0, '00288': 0, '00289': 0, '00290': 0, '00291': 1, '00293': 1, '00294': 1, '00296': 1, '00297': 0, '00298': 0, '00299': 1, '00300': 0, '00301': 0, '00303': 1, '00304': 1, '00305': 1, '00306': 1, '00308': 0, '00309': 0, '00310': 0, '00311': 1, '00312': 0, '00313': 1, '00314': 0, '00316': 0, '00317': 1, '00318': 0, '00320': 0, '00321': 1, '00322': 1, '00324': 0, '00325': 0, '00327': 0, '00328': 1, '00329': 1, '00331': 1, '00332': 1, '00334': 1, '00336': 0, '00338': 1, '00339': 0, '00340': 1, '00341': 0, '00343': 0, '00344': 1, '00346': 0, '00347': 0, '00348': 0, '00349': 0, '00350': 1, '00351': 0, '00352': 1, '00353': 0, '00356': 0, '00359': 1, '00360': 1, '00364': 1, '00366': 1, '00367': 1, '00369': 1, '00370': 1, '00371': 1, '00373': 0, '00376': 0, '00377': 0, '00378': 0, '00379': 0, '00380': 0, '00382': 0, '00383': 1, '00386': 1, '00387': 0, '00388': 0, '00389': 0, '00390': 0, '00391': 0, '00392': 0, '00395': 0, '00397': 0, '00399': 0, '00400': 1, '00401': 0, '00402': 0, '00403': 1, '00404': 1, '00405': 0, '00406': 1, '00407': 0, '00408': 1, '00409': 1, '00410': 0, '00412': 0, '00413': 1, '00414': 0, '00416': 1, '00417': 0, '00418': 0, '00419': 0, '00421': 0, '00423': 0, '00425': 1, '00426': 1, '00429': 1, '00430': 0, '00431': 1, '00432': 0, '00433': 0, '00436': 1, '00440': 1, '00441': 0, '00442': 1, '00443': 1, '00444': 0, '00445': 0, '00446': 0, '00449': 1, '00451': 1, '00452': 0, '00454': 0, '00455': 0, '00456': 1, '00457': 1, '00459': 0, '00464': 0, '00466': 1, '00468': 1, '00469': 0, '00470': 1, '00472': 1, '00477': 0, '00478': 1, '00479': 1, '00480': 1, '00481': 0, '00483': 1, '00485': 1, '00488': 1, '00491': 1, '00493': 1, '00494': 1, '00 ...
# Patient 658 Num Slices 392
# Affine tranformation - slice 0
# Affine tranformation - slice 1
# Affine tranformation - slice 2
# Affine tranformation - slice 3
# Affine tranformation - slice 4
# Affine tranformation - slice 5
# Affine tranformation - slice 6
# Affine tranformation - slice 7
# Affine tranformation - slice 8
# Affine tranformation - slice 9
# Affine tranformation - slice 10
# Affine tranformation - slice 11
# Affine tranformation - slice 12
# Affine tranformation - slice 13
# Affine tranformation - slice 14
# Affine tranformation - slice 15
# Affine tranformation - slice 16
# Affine tranformation - slice 17
# Affine tranformation - slice 18
# Affine tranformation - slice 19
# Affine tranformation - slice 20
# Affine tranformation - slice 21
# Affine tranformation - slice 22
# Affine tranformation - slice 23
# Affine tranformation - slice 24
# Affine tranformation - slice 25
# Affine tranformation - slice 26
# Affine tranformation - slice 27
# Affine tranformation - slice 28
# Affine tranformation - slice 29
# Affine tranformation - slice 30
# Affine tranformation - slice 31
# Affine tranformation - slice 32
# Affine tranformation - slice 33
# Affine tranformation - slice 34
# Affine tranformation - slice 35
# Affine tranformation - slice 36
# Affine tranformation - slice 37
# Affine tranformation - slice 38
# Affine tranformation - slice 39
# Affine tranformation - slice 40
# Affine tranformation - slice 41
# Affine tranformation - slice 42
# Affine tranformation - slice 43
# Affine tranformation - slice 44
# Affine tranformation - slice 45
# Affine tranformation - slice 46
# Affine tranformation - slice 47
# Affine tranformation - slice 48
# Affine tranformation - slice 49
# Affine tranformation - slice 50
# Affine tranformation - slice 51
# Affine tranformation - slice 52
# Affine tranformation - slice 53
# Affine tranformation - slice 54
# Affine tranformation - slice 55
# Affine tranformation - slice 56
# Affine tranformation - slice 57
# Affine tranformation - slice 58
# Affine tranformation - slice 59
# Affine tranformation - slice 60
# Affine tranformation - slice 61
# Affine tranformation - slice 62
# Affine tranformation - slice 63
# Affine tranformation - slice 64
# Affine tranformation - slice 65
# Affine tranformation - slice 66
# Affine tranformation - slice 67
# Affine tranformation - slice 68
# Affine tranformation - slice 69
# Affine tranformation - slice 70
# Affine tranformation - slice 71
# Affine tranformation - slice 72
# Affine tranformation - slice 73
# Affine tranformation - slice 74
# Affine tranformation - slice 75
# Affine tranformation - slice 76
# Affine tranformation - slice 77
# Affine tranformation - slice 78
# Affine tranformation - slice 79
# Affine tranformation - slice 80
# Affine tranformation - slice 81
# Affine tranformation - slice 82
# Affine tranformation - slice 83
# Affine tranformation - slice 84
# Affine tranformation - slice 85
# Affine tranformation - slice 86
# Affine tranformation - slice 87
# Affine tranformation - slice 88
# Affine tranformation - slice 89
# Affine tranformation - slice 90
# Affine tranformation - slice 91
# Affine tranformation - slice 92
# Affine tranformation - slice 93
# Affine tranformation - slice 94
# Affine tranformation - slice 95
# Affine tranformation - slice 96
# Affine tranformation - slice 97
# Affine tranformation - slice 98
# Affine tranformation - slice 99
# Affine tranformation - slice 100
# Affine tranformation - slice 101
# Affine tranformation - slice 102
# Affine tranformation - slice 103
# Affine tranformation - slice 104
# Affine tranformation - slice 105
# Affine tranformation - slice 106
# Affine tranformation - slice 107
# Affine tranformation - slice 108
# Affine tranformation - slice 109
# Affine tranformation - slice 110
# Affine tranformation - slice 111
# Affine tranformation - slice 112
# Affine tranformation - slice 113
# Affine tranformation - slice 114
# Affine tranformation - slice 115
# Affine tranformation - slice 116
# Affine tranformation - slice 117
# Affine tranformation - slice 118
# Affine tranformation - slice 119
# Affine tranformation - slice 120
# Affine tranformation - slice 121
# Affine tranformation - slice 122
# Affine tranformation - slice 123
# Affine tranformation - slice 124
# Affine tranformation - slice 125
# Affine tranformation - slice 126
# Affine tranformation - slice 127
# Affine tranformation - slice 128
# Affine tranformation - slice 129
# Affine tranformation - slice 130
# Affine tranformation - slice 131
# Affine tranformation - slice 132
# Affine tranformation - slice 133
# Affine tranformation - slice 134
# Affine tranformation - slice 135
# Affine tranformation - slice 136
# Affine tranformation - slice 137
# Affine tranformation - slice 138
# Affine tranformation - slice 139
# Affine tranformation - slice 140
# Affine tranformation - slice 141
# Affine tranformation - slice 142
# Affine tranformation - slice 143
# Affine tranformation - slice 144
# Affine tranformation - slice 145
# Affine tranformation - slice 146
# Affine tranformation - slice 147
# Affine tranformation - slice 148
# Affine tranformation - slice 149
# Affine tranformation - slice 150
# Affine tranformation - slice 151
# Affine tranformation - slice 152
# Affine tranformation - slice 153
# Affine tranformation - slice 154
# Affine tranformation - slice 155
# Affine tranformation - slice 156
# Affine tranformation - slice 157
# Affine tranformation - slice 158
# Affine tranformation - slice 159
# Affine tranformation - slice 160
# Affine tranformation - slice 161
# Affine tranformation - slice 162
# Affine tranformation - slice 163
# Affine tranformation - slice 164
# Affine tranformation - slice 165
# Affine tranformation - slice 166
# Affine tranformation - slice 167
# Affine tranformation - slice 168
# Affine tranformation - slice 169
# Affine tranformation - slice 170
# Affine tranformation - slice 171
# Affine tranformation - slice 172
# Affine tranformation - slice 173
# Affine tranformation - slice 174
# Affine tranformation - slice 175
# Affine tranformation - slice 176
# Affine tranformation - slice 177
# Affine tranformation - slice 178
# Affine tranformation - slice 179
# Affine tranformation - slice 180
# Affine tranformation - slice 181
# Affine tranformation - slice 182
# Affine tranformation - slice 183
# Affine tranformation - slice 184
# Affine tranformation - slice 185
# Affine tranformation - slice 186
# Affine tranformation - slice 187
# Affine tranformation - slice 188
# Affine tranformation - slice 189
# Affine tranformation - slice 190
# Affine tranformation - slice 191
# Affine tranformation - slice 192
# Affine tranformation - slice 193
# Affine tranformation - slice 194
# Affine tranformation - slice 195
# Affine tranformation - slice 196
# Affine tranformation - slice 197
# Affine tranformation - slice 198
# Affine tranformation - slice 199
# Affine tranformation - slice 200
# Affine tranformation - slice 201
# Affine tranformation - slice 202
# Affine tranformation - slice 203
# Affine tranformation - slice 204
# Affine tranformation - slice 205
# Affine tranformation - slice 206
# Affine tranformation - slice 207
# Affine tranformation - slice 208
# Affine tranformation - slice 209
# Affine tranformation - slice 210
# Affine tranformation - slice 211
# Affine tranformation - slice 212
# Affine tranformation - slice 213
# Affine tranformation - slice 214
# Affine tranformation - slice 215
# Affine tranformation - slice 216
# Affine tranformation - slice 217
# Affine tranformation - slice 218
# Affine tranformation - slice 219
# Affine tranformation - slice 220
# Affine tranformation - slice 221
# Affine tranformation - slice 222
# Affine tranformation - slice 223
# Affine tranformation - slice 224
# Affine tranformation - slice 225
# Affine tranformation - slice 226
# Affine tranformation - slice 227
# Affine tranformation - slice 228
# Affine tranformation - slice 229
# Affine tranformation - slice 230
# Affine tranformation - slice 231
# Affine tranformation - slice 232
# Affine tranformation - slice 233
# Affine tranformation - slice 234
# Affine tranformation - slice 235
# Affine tranformation - slice 236
# Affine tranformation - slice 237
# Affine tranformation - slice 238
# Affine tranformation - slice 239
# Affine tranformation - slice 240
# Affine tranformation - slice 241
# Affine tranformation - slice 242
# Affine tranformation - slice 243
# Affine tranformation - slice 244
# Affine tranformation - slice 245
# Affine tranformation - slice 246
# Affine tranformation - slice 247
# Affine tranformation - slice 248
# Affine tranformation - slice 249
# Affine tranformation - slice 250
# Affine tranformation - slice 251
# Affine tranformation - slice 252
# Affine tranformation - slice 253
# Affine tranformation - slice 254
# Affine tranformation - slice 255
# Affine tranformation - slice 256
# Affine tranformation - slice 257
# Affine tranformation - slice 258
# Affine tranformation - slice 259
# Affine tranformation - slice 260
# Affine tranformation - slice 261
# Affine tranformation - slice 262
# Affine tranformation - slice 263
# Affine tranformation - slice 264
# Affine tranformation - slice 265
# Affine tranformation - slice 266
# Affine tranformation - slice 267
# Affine tranformation - slice 268
# Affine tranformation - slice 269
# Affine tranformation - slice 270
# Affine tranformation - slice 271
# Affine tranformation - slice 272
# Affine tranformation - slice 273
# Affine tranformation - slice 274
# Affine tranformation - slice 275
# Affine tranformation - slice 276
# Affine tranformation - slice 277
# Affine tranformation - slice 278
# Affine tranformation - slice 279
# Affine tranformation - slice 280
# Affine tranformation - slice 281
# Affine tranformation - slice 282
# Affine tranformation - slice 283
# Affine tranformation - slice 284
# Affine tranformation - slice 285
# Affine tranformation - slice 286
# Affine tranformation - slice 287
# Affine tranformation - slice 288
# Affine tranformation - slice 289
# Affine tranformation - slice 290
# Affine tranformation - slice 291
# Affine tranformation - slice 292
# Affine tranformation - slice 293
# Affine tranformation - slice 294
# Affine tranformation - slice 295
# Affine tranformation - slice 296
# Affine tranformation - slice 297
# Affine tranformation - slice 298
# Affine tranformation - slice 299
# Affine tranformation - slice 300
# Affine tranformation - slice 301
# Affine tranformation - slice 302
# Affine tranformation - slice 303
# Affine tranformation - slice 304
# Affine tranformation - slice 305
# Affine tranformation - slice 306
# Affine tranformation - slice 307
# Affine tranformation - slice 308
# Affine tranformation - slice 309
# Affine tranformation - slice 310
# Affine tranformation - slice 311
# Affine tranformation - slice 312
# Affine tranformation - slice 313
# Affine tranformation - slice 314
# Affine tranformation - slice 315
# Affine tranformation - slice 316
# Affine tranformation - slice 317
# Affine tranformation - slice 318
# Affine tranformation - slice 319
# Affine tranformation - slice 320
# Affine tranformation - slice 321
# Affine tranformation - slice 322
# Affine tranformation - slice 323
# Affine tranformation - slice 324
# Affine tranformation - slice 325
# Affine tranformation - slice 326
# Affine tranformation - slice 327
# Affine tranformation - slice 328
# Affine tranformation - slice 329
# Affine tranformation - slice 330
# Affine tranformation - slice 331
# Affine tranformation - slice 332
# Affine tranformation - slice 333
# Affine tranformation - slice 334
# Affine tranformation - slice 335
# Affine tranformation - slice 336
# Affine tranformation - slice 337
# Affine tranformation - slice 338
# Affine tranformation - slice 339
# Affine tranformation - slice 340
# Affine tranformation - slice 341
# Affine tranformation - slice 342
# Affine tranformation - slice 343
# Affine tranformation - slice 344
# Affine tranformation - slice 345
# Affine tranformation - slice 346
# Affine tranformation - slice 347
# Affine tranformation - slice 348
# Affine tranformation - slice 349
# Affine tranformation - slice 350
# Affine tranformation - slice 351
# Affine tranformation - slice 352
# Affine tranformation - slice 353
# Affine tranformation - slice 354
# Affine tranformation - slice 355
# Affine tranformation - slice 356
# Affine tranformation - slice 357
# Affine tranformation - slice 358
# Affine tranformation - slice 359
# Affine tranformation - slice 360
# Affine tranformation - slice 361
# Affine tranformation - slice 362
# Affine tranformation - slice 363
# Affine tranformation - slice 364
# Affine tranformation - slice 365
# Affine tranformation - slice 366
# Affine tranformation - slice 367
# Affine tranformation - slice 368
# Affine tranformation - slice 369
# Affine tranformation - slice 370
# Affine tranformation - slice 371
# Affine tranformation - slice 372
# Affine tranformation - slice 373
# Affine tranformation - slice 374
# Affine tranformation - slice 375
# Affine tranformation - slice 376
# Affine tranformation - slice 377
# Affine tranformation - slice 378
# Affine tranformation - slice 379
# Affine tranformation - slice 380
# Affine tranformation - slice 381
# Affine tranformation - slice 382
# Affine tranformation - slice 383
# Affine tranformation - slice 384
# Affine tranformation - slice 385
# Affine tranformation - slice 386
# Affine tranformation - slice 387
# Affine tranformation - slice 388
# Affine tranformation - slice 389
# Affine tranformation - slice 390
# Affine tranformation - slice 391
# Affine transformation completed
# Compression started, scale: (0.125000,0.125000,0.125000)
# Compression completed
# Nearest Neighbor interpolation started
# Uniform interpolation done
# Nearest Neighbor interpolation completed
# Creating patches
# Final patch count: 1
# Creating Patches completed
# Saving patches for patient %s 00658
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/9d/y_l_7__j5cx757qqhp4x97_80000gn/T/ipykernel_6335/3780733796.py in <module>
#     293     patches = create_patches(interpolated_image)
#     294     print("Creating Patches completed")
# --> 295     save_patches(patient_folder,patches)
#     296     print("Save Patches completed")
#     297     break
#
# /var/folders/9d/y_l_7__j5cx757qqhp4x97_80000gn/T/ipykernel_6335/3780733796.py in save_patches(patient_id, patches)
#     249         patch_array = np.array(patch)
#     250         output_file = 'Dicom/dicom_' + patient_id + '_' + str(patch_num) + '.npy'
# --> 251         save(output_file, patch_array)
#     252     return patches
#     253
#
# <__array_function__ internals> in save(*args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/lib/npyio.py in save(file, arr, allow_pickle, fix_imports)
#     523         if not file.endswith('.npy'):
#     524             file = file + '.npy'
# --> 525         file_ctx = open(file, "wb")
#     526
#     527     with file_ctx as fid:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Dicom/dicom_00658_0.npy'
